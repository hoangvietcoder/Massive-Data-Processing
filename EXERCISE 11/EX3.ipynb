# %%
# Import the Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Dataset
data = pd.read_csv("https://raw.githubusercontent.com/TracyRenee61/Wine/main/wine.data") 
data.columns =['y', 'alcohol', 'malic_acid', 'ash', 'alcalinity', 'magnesium', 'phenols', 'flavanoids', 'nonflavanoid', 'proanthocyanins', 'color', 'hue', 'diluted', 'proline']
data
# Out:
#      y  alcohol  malic_acid   ash  alcalinity  magnesium  phenols  flavanoids  \
# 0    1    13.20        1.78  2.14        11.2        100     2.65        2.76
# 1    1    13.16        2.36  2.67        18.6        101     2.80        3.24
# 2    1    14.37        1.95  2.50        16.8        113     3.85        3.49
# 3    1    13.24        2.59  2.87        21.0        118     2.80        2.69
# 4    1    14.20        1.76  2.45        15.2        112     3.27        3.39
# ..  ..      ...         ...   ...         ...        ...      ...         ...
# 172  3    13.71        5.65  2.45        20.5         95     1.68        0.61
# 173  3    13.40        3.91  2.48        23.0        102     1.80        0.75
# 174  3    13.27        4.28  2.26        20.0        120     1.59        0.69
# 175  3    13.17        2.59  2.37        20.0        120     1.65        0.68
# 176  3    14.13        4.10  2.74        24.5         96     2.05        0.76
#
#      nonflavanoid  proanthocyanins  color   hue  diluted  proline
# 0            0.26             1.28   4.38  1.05     3.40     1050
# 1            0.30             2.81   5.68  1.03     3.17     1185
# 2            0.24             2.18   7.80  0.86     3.45     1480
# 3            0.39             1.82   4.32  1.04     2.93      735
# 4            0.34             1.97   6.75  1.05     2.85     1450
# ..            ...              ...    ...   ...      ...      ...
# 172          0.52             1.06   7.70  0.64     1.74      740
# 173          0.43             1.41   7.30  0.70     1.56      750
# 174          0.43             1.35  10.20  0.59     1.56      835
# 175          0.53             1.46   9.30  0.60     1.62      840
# 176          0.56             1.35   9.20  0.61     1.60      560
#
# [177 rows x 14 columns]

# %%
# Check for null values
data.isnull().sum()
# Out:
# y                  0
# alcohol            0
# malic_acid         0
# ash                0
# alcalinity         0
# magnesium          0
# phenols            0
# flavanoids         0
# nonflavanoid       0
# proanthocyanins    0
# color              0
# hue                0
# diluted            0
# proline            0
# dtype: int64

# %%
# Exploratory data analysis
corrmat = data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# Define X and y
y = data.y
X = data.drop(['y'], axis=1)

# %%
X
# Out:
#      alcohol  malic_acid   ash  alcalinity  magnesium  phenols  flavanoids  \
# 0      13.20        1.78  2.14        11.2        100     2.65        2.76
# 1      13.16        2.36  2.67        18.6        101     2.80        3.24
# 2      14.37        1.95  2.50        16.8        113     3.85        3.49
# 3      13.24        2.59  2.87        21.0        118     2.80        2.69
# 4      14.20        1.76  2.45        15.2        112     3.27        3.39
# ..       ...         ...   ...         ...        ...      ...         ...
# 172    13.71        5.65  2.45        20.5         95     1.68        0.61
# 173    13.40        3.91  2.48        23.0        102     1.80        0.75
# 174    13.27        4.28  2.26        20.0        120     1.59        0.69
# 175    13.17        2.59  2.37        20.0        120     1.65        0.68
# 176    14.13        4.10  2.74        24.5         96     2.05        0.76
#
#      nonflavanoid  proanthocyanins  color   hue  diluted  proline
# 0            0.26             1.28   4.38  1.05     3.40     1050
# 1            0.30             2.81   5.68  1.03     3.17     1185
# 2            0.24             2.18   7.80  0.86     3.45     1480
# 3            0.39             1.82   4.32  1.04     2.93      735
# 4            0.34             1.97   6.75  1.05     2.85     1450
# ..            ...              ...    ...   ...      ...      ...
# 172          0.52             1.06   7.70  0.64     1.74      740
# 173          0.43             1.41   7.30  0.70     1.56      750
# 174          0.43             1.35  10.20  0.59     1.56      835
# 175          0.53             1.46   9.30  0.60     1.62      840
# 176          0.56             1.35   9.20  0.61     1.60      560
#
# [177 rows x 13 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 172    3
# 173    3
# 174    3
# 175    3
# 176    3
# Name: y, Length: 177, dtype: int64

# %%
# Normalise data
X = (X - X.min()) / (X.max() - X.min())
X
# Out:
#       alcohol  malic_acid       ash  alcalinity  magnesium   phenols  \
# 0    0.571053    0.205534  0.417112    0.030928   0.326087  0.575862
# 1    0.560526    0.320158  0.700535    0.412371   0.336957  0.627586
# 2    0.878947    0.239130  0.609626    0.319588   0.467391  0.989655
# 3    0.581579    0.365613  0.807487    0.536082   0.521739  0.627586
# 4    0.834211    0.201581  0.582888    0.237113   0.456522  0.789655
# ..        ...         ...       ...         ...        ...       ...
# 172  0.705263    0.970356  0.582888    0.510309   0.271739  0.241379
# 173  0.623684    0.626482  0.598930    0.639175   0.347826  0.282759
# 174  0.589474    0.699605  0.481283    0.484536   0.543478  0.210345
# 175  0.563158    0.365613  0.540107    0.484536   0.543478  0.231034
# 176  0.815789    0.664032  0.737968    0.716495   0.282609  0.368966
#
#      flavanoids  nonflavanoid  proanthocyanins     color       hue   diluted  \
# 0      0.510549      0.245283         0.274448  0.264505  0.463415  0.780220
# 1      0.611814      0.320755         0.757098  0.375427  0.447154  0.695971
# 2      0.664557      0.207547         0.558360  0.556314  0.308943  0.798535
# 3      0.495781      0.490566         0.444795  0.259386  0.455285  0.608059
# 4      0.643460      0.396226         0.492114  0.466724  0.463415  0.578755
# ..          ...           ...              ...       ...       ...       ...
# 172    0.056962      0.735849         0.205047  0.547782  0.130081  0.172161
# 173    0.086498      0.566038         0.315457  0.513652  0.178862  0.106227
# 174    0.073840      0.566038         0.296530  0.761092  0.089431  0.106227
# 175    0.071730      0.754717         0.331230  0.684300  0.097561  0.128205
# 176    0.088608      0.811321         0.296530  0.675768  0.105691  0.120879
#
#       proline
# 0    0.550642
# 1    0.646933
# 2    0.857347
# 3    0.325963
# 4    0.835949
# ..        ...
# 172  0.329529
# 173  0.336662
# 174  0.397290
# 175  0.400856
# 176  0.201141
#
# [177 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# Split into validation and training data
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=1, shuffle=True)
X_train.shape, X_val.shape, y_train.shape,y_val.shape
# Out:
# ((123, 13), (54, 13), (123,), (54,))

# %%
# Define model
from sklearn.neighbors import RadiusNeighborsClassifier

model = RadiusNeighborsClassifier(radius=1.0, weights='distance').fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# 1.0

# %%
# Predict on validation set
y_pred = model.predict(X_val)
print(model.score(X_val, y_val))
# Out:
# 0.9629629629629629

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_val, y_pred)
# Out:
# array([[21,  1,  0],
#        [ 1, 23,  0],
#        [ 0,  0,  8]])

# %%
df=pd.DataFrame({'Actual': y_val, 'Predicted':y_pred})
df
# Out:
#      Actual  Predicted
# 95        2          2
# 116       2          2
# 19        1          1
# 69        2          2
# 53        1          1
# 153       3          3
# 120       2          1
# 14        1          1
# 102       2          2
# 106       2          2
# 11        1          1
# 4         1          1
# 107       2          2
# 42        1          2
# 114       2          2
# 112       2          2
# 151       3          3
# 35        1          1
# 125       2          2
# 31        1          1
# 51        1          1
# 75        2          2
# 171       3          3
# 73        2          2
# 40        1          1
# 85        2          2
# 47        1          1
# 29        1          1
# 16        1          1
# 110       2          2
# 155       3          3
# 158       3          3
# 150       3          3
# 5         1          1
# 97        2          2
# 91        2          2
# 90        2          2
# 169       3          3
# 113       2          2
# 48        1          1
# 54        1          1
# 59        2          2
# 108       2          2
# 39        1          1
# 56        1          1
# 44        1          1
# 81        2          2
# 33        1          1
# 18        1          1
# 58        2          2
# 126       2          2
# 78        2          2
# 147       3          3
# 12        1          1

# %%
# PCA 
from sklearn.decomposition import PCA

pca_val = PCA(n_components=2)
principalComponents_val = pca_val.fit_transform(X_val)

plt.figure(figsize = (12, 8))
plt.scatter(principalComponents_val[:, 0], principalComponents_val[:,1], c = y_pred == y_val - 1, alpha = .8, s = 50)
